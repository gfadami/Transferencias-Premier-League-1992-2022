# %% [markdown]
# # Análise de Dados e Separação de Times

# %% [markdown]
# #### Fonte de dados: https://www.kaggle.com/datasets/cbhavik/football-transfers-from-199293-to-202122-seasons

# %% [markdown]
# ## Separar dataframes de transferências dos 6 principais times da Premier League:
# ## Arsenal, Chelsea, Liverpool, Manchester City, Manchester United e Tottenham

# %% [markdown]
# ### Observação
#
# ### 1 - Depois de checar no site transfermarket, os valores de 'fee' = '-' or '?' foram substituídos por 0.0, pois descobrimos que foram transferências sem custos.
# ### 2 - Os valores de 'fee_cleaned' estão em milhões de euros.

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/premier-league.csv')
dados.head(50)
# Out:
#               club_name       player_name   age            position  \
# 0      Middlesbrough FC      Tommy Wright  26.0         Left Winger
# 1      Middlesbrough FC  Jonathan Gittens  28.0             defence
# 2      Middlesbrough FC      Chris Morris  28.0          Right-Back
# 3      Middlesbrough FC       Ben Roberts  17.0          Goalkeeper
# 4      Middlesbrough FC         Andy Todd  17.0         Centre-Back
# 5      Middlesbrough FC     Stuart Ripley  24.0        Right Winger
# 6      Middlesbrough FC    Gary Parkinson  24.0          Right-Back
# 7      Middlesbrough FC     Bernie Slaven  31.0      Centre-Forward
# 8      Middlesbrough FC       Andy Payton  24.0              attack
# 9      Middlesbrough FC        Ian Arnold  20.0      Centre-Forward
# 10     Middlesbrough FC   Dwight Marshall  27.0              attack
# 11         Norwich City       Mark Robins  22.0      Centre-Forward
# 12         Norwich City       Gary Megson  33.0  Defensive Midfield
# 13         Norwich City       Mark Peters  19.0             defence
# 14         Norwich City      Darren Eadie  17.0       Left Midfield
# 15         Norwich City      Andy Johnson  18.0  Attacking Midfield
# 16         Norwich City         Lee Power  20.0      Centre-Forward
# 17         Norwich City      Tim Sherwood  23.0    Central Midfield
# 18         Norwich City       Paul Blades  27.0          Right-Back
# 19         Norwich City        Steve Ball  22.0            midfield
# 20         Norwich City    Adrian Pennock  21.0            midfield
# 21         Norwich City      Robert Fleck  26.0      Centre-Forward
# 22         Norwich City        Colin Loss  18.0      Right Midfield
# 23         Norwich City    David Williams  37.0            midfield
# 24      Oldham Athletic         Ian Olney  22.0      Centre-Forward
# 25      Oldham Athletic      Neil Pointon  27.0           Left-Back
# 26      Oldham Athletic     Steve Redmond  24.0         Centre-Back
# 27      Oldham Athletic       Chris Makin  19.0           Left-Back
# 28      Oldham Athletic      Paul Gerrard  19.0          Goalkeeper
# 29      Oldham Athletic       Chris Makin  19.0           Left-Back
# 30      Oldham Athletic      Paul Moulden  24.0              attack
# 31      Oldham Athletic       Chris Makin  19.0           Left-Back
# 32      Oldham Athletic       Rick Holden  27.0       Left Midfield
# 33      Oldham Athletic      Mike Fillery  31.0            midfield
# 34      Oldham Athletic      Paul Moulden  24.0              attack
# 35  Queens Park Rangers     Darren Finlay  18.0            midfield
# 36  Queens Park Rangers      Kevin Gallen  17.0      Centre-Forward
# 37  Queens Park Rangers      Gary Waddock  30.0  Defensive Midfield
# 38  Queens Park Rangers      Andy Tillson  26.0             defence
# 39  Queens Park Rangers   Justin Channing  23.0            midfield
# 40  Queens Park Rangers      Gary Waddock  30.0  Defensive Midfield
# 41  Sheffield Wednesday       Mark Bright  30.0      Centre-Forward
# 42  Sheffield Wednesday      Chris Waddle  31.0  Attacking Midfield
# 43  Sheffield Wednesday     Simon Stewart  18.0             defence
# 44  Sheffield Wednesday  Marlon Beresford  22.0          Goalkeeper
# 45  Sheffield Wednesday     Paul Williams  27.0              attack
# 46         Wimbledon FC   Dean Holdsworth  23.0      Centre-Forward
# 47         Wimbledon FC      Vinnie Jones  27.0  Defensive Midfield
# 48         Wimbledon FC        Greg Berry  21.0            midfield
# 49         Wimbledon FC        Peter Fear  18.0            midfield
#
#    club_involved_name                      fee transfer_movement  \
# 0           Leicester                  €910Th.                in
# 1         Southampton                  €250Th.                in
# 2              Celtic                        ?                in
# 3            Boro U18                        -                in
# 4            Boro U18                        -                in
# 5           Blackburn                   €2.00m               out
# 6     Southend United            loan transfer               out
# 7           Port Vale                        ?               out
# 8              Celtic                        ?               out
# 9     Carlisle United                        ?               out
# 10           Plymouth  End of loanMay 31, 1993               out
# 11            Man Utd                   €1.00m                in
# 12           Man City            free transfer                in
# 13           Man City            free transfer                in
# 14        Norwich U18                        -                in
# 15        Norwich U18                        -                in
# 16           Charlton  End of loanMay 31, 1993                in
# 17          Blackburn                  €750Th.               out
# 18             Wolves                  €378Th.               out
# 19     Cambridge Utd.            free transfer               out
# 20        Bournemouth                   €36Th.               out
# 21            Chelsea                        ?               out
# 22              Derby                        ?               out
# 23            Retired                        -               out
# 24        Aston Villa                  €894Th.                in
# 25           Man City                  €675Th.                in
# 26           Man City                  €450Th.                in
# 27         Oldham U18                        -                in
# 28         Oldham U18                        -                in
# 29              Wigan   End of loanMay 1, 1993                in
# 30              Molde  End of loanJun 30, 1992                in
# 31              Wigan            loan transfer               out
# 32           Man City                        ?               out
# 33       Crawley Town                        ?               out
# 34           Brighton            loan transfer               out
# 35            QPR U18                        -                in
# 36            QPR U18                        -                in
# 37       Swindon Town  End of loanJun 30, 1992                in
# 38       Grimsby Town            loan transfer               out
# 39     Bristol Rovers                        ?               out
# 40     Bristol Rovers                        ?               out
# 41     Crystal Palace                   €1.70m                in
# 42          Marseille                   €1.50m                in
# 43      Sheff Wed U18                        -                in
# 44            Burnley                  €140Th.               out
# 45     Crystal Palace                        ?               out
# 46          Brentford                   €1.00m                in
# 47            Chelsea                  €830Th.                in
# 48      Leyton Orient                  €313Th.                in
# 49            Unknown                        ?                in
#
#    transfer_period  fee_cleaned     league_name  year     season
# 0           Summer        0.910  Premier League  1992  1992/1993
# 1           Summer        0.250  Premier League  1992  1992/1993
# 2           Summer          NaN  Premier League  1992  1992/1993
# 3           Summer          NaN  Premier League  1992  1992/1993
# 4           Summer          NaN  Premier League  1992  1992/1993
# 5           Summer        2.000  Premier League  1992  1992/1993
# 6           Summer          NaN  Premier League  1992  1992/1993
# 7           Summer          NaN  Premier League  1992  1992/1993
# 8           Summer          NaN  Premier League  1992  1992/1993
# 9           Summer          NaN  Premier League  1992  1992/1993
# 10          Summer          NaN  Premier League  1992  1992/1993
# 11          Summer        1.000  Premier League  1992  1992/1993
# 12          Summer        0.000  Premier League  1992  1992/1993
# 13          Summer        0.000  Premier League  1992  1992/1993
# 14          Summer          NaN  Premier League  1992  1992/1993
# 15          Summer          NaN  Premier League  1992  1992/1993
# 16          Summer          NaN  Premier League  1992  1992/1993
# 17          Summer        0.750  Premier League  1992  1992/1993
# 18          Summer        0.378  Premier League  1992  1992/1993
# 19          Summer        0.000  Premier League  1992  1992/1993
# 20          Summer        0.036  Premier League  1992  1992/1993
# 21          Summer          NaN  Premier League  1992  1992/1993
# 22          Summer          NaN  Premier League  1992  1992/1993
# 23          Summer          NaN  Premier League  1992  1992/1993
# 24          Summer        0.894  Premier League  1992  1992/1993
# 25          Summer        0.675  Premier League  1992  1992/1993
# 26          Summer        0.450  Premier League  1992  1992/1993
# 27          Summer          NaN  Premier League  1992  1992/1993
# 28          Summer          NaN  Premier League  1992  1992/1993
# 29          Summer          NaN  Premier League  1992  1992/1993
# 30          Summer          NaN  Premier League  1992  1992/1993
# 31          Summer          NaN  Premier League  1992  1992/1993
# 32          Summer          NaN  Premier League  1992  1992/1993
# 33          Summer          NaN  Premier League  1992  1992/1993
# 34          Summer          NaN  Premier League  1992  1992/1993
# 35          Summer          NaN  Premier League  1992  1992/1993
# 36          Summer          NaN  Premier League  1992  1992/1993
# 37          Summer          NaN  Premier League  1992  1992/1993
# 38          Summer          NaN  Premier League  1992  1992/1993
# 39          Summer          NaN  Premier League  1992  1992/1993
# 40          Summer          NaN  Premier League  1992  1992/1993
# 41          Summer        1.700  Premier League  1992  1992/1993
# 42          Summer        1.500  Premier League  1992  1992/1993
# 43          Summer          NaN  Premier League  1992  1992/1993
# 44          Summer        0.140  Premier League  1992  1992/1993
# 45          Summer          NaN  Premier League  1992  1992/1993
# 46          Summer        1.000  Premier League  1992  1992/1993
# 47          Summer        0.830  Premier League  1992  1992/1993
# 48          Summer        0.313  Premier League  1992  1992/1993
# 49          Summer          NaN  Premier League  1992  1992/1993

# %%
dados.dtypes
# Out:
# club_name              object
# player_name            object
# age                   float64
# position               object
# club_involved_name     object
# fee                    object
# transfer_movement      object
# transfer_period        object
# fee_cleaned           float64
# league_name            object
# year                    int64
# season                 object
# dtype: object

# %%
dados.fee_cleaned
# Out:
# 0        0.91
# 1        0.25
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 22970     NaN
# 22971     NaN
# 22972     NaN
# 22973     NaN
# 22974     NaN
# Name: fee_cleaned, Length: 22975, dtype: float64

# %%
dados['fee_cleaned'].describe()
# Out:
# count    8739.000000
# mean        4.076735
# std         8.981443
# min         0.000000
# 25%         0.000000
# 50%         0.700000
# 75%         4.000000
# max       135.000000
# Name: fee_cleaned, dtype: float64

# %%
print(f'A base de dados apresenta {dados.shape[0]} registros de transferências e {dados.shape[1]} variáveis.')
# Out:
# A base de dados apresenta 22975 registros de transferências e 12 variáveis.

# %%
dados['club_name'].unique()
# Out:
# array(['Middlesbrough FC', 'Norwich City', 'Oldham Athletic',
#        'Queens Park Rangers', 'Sheffield Wednesday', 'Wimbledon FC',
#        'Coventry City', 'Manchester United', 'Crystal Palace',
#        'Nottingham Forest', 'Ipswich Town', 'Arsenal FC', 'Chelsea FC',
#        'Aston Villa', 'Leeds United', 'Sheffield United',
#        'Manchester City', 'Southampton FC', 'Blackburn Rovers',
#        'Tottenham Hotspur', 'Liverpool FC', 'Everton FC',
#        'Newcastle United', 'West Ham United', 'Swindon Town',
#        'Leicester City', 'Bolton Wanderers', 'Sunderland AFC',
#        'Derby County', 'Barnsley FC', 'Charlton Athletic',
#        'Bradford City', 'Watford FC', 'Fulham FC', 'West Bromwich Albion',
#        'Birmingham City', 'Portsmouth FC', 'Wolverhampton Wanderers',
#        'Wigan Athletic', 'Reading FC', 'Stoke City', 'Hull City',
#        'Burnley FC', 'Blackpool FC', 'Swansea City', 'Cardiff City',
#        'AFC Bournemouth', 'Brighton & Hove Albion', 'Huddersfield Town',
#        'Brentford FC'], dtype=object)

# %%
dados['club_name'].value_counts()
# Out:
# Chelsea FC                 1273
# Tottenham Hotspur          1196
# West Ham United            1068
# Manchester City            1055
# Liverpool FC               1051
# Manchester United           980
# Newcastle United            959
# Arsenal FC                  934
# Everton FC                  933
# Aston Villa                 929
# Sunderland AFC              822
# Southampton FC              764
# Blackburn Rovers            735
# Fulham FC                   694
# Middlesbrough FC            557
# Leicester City              539
# Bolton Wanderers            533
# Crystal Palace              504
# West Bromwich Albion        461
# Portsmouth FC               442
# Wolverhampton Wanderers     433
# Watford FC                  419
# Stoke City                  417
# Norwich City                402
# Leeds United                398
# Birmingham City             342
# Wigan Athletic              339
# Queens Park Rangers         313
# Charlton Athletic           307
# Swansea City                304
# Coventry City               275
# Brighton & Hove Albion      264
# Derby County                256
# Hull City                   255
# Burnley FC                  253
# Sheffield Wednesday         206
# AFC Bournemouth             203
# Sheffield United            193
# Reading FC                  179
# Wimbledon FC                154
# Nottingham Forest           145
# Ipswich Town                101
# Cardiff City                 98
# Huddersfield Town            73
# Bradford City                64
# Blackpool FC                 50
# Brentford FC                 34
# Oldham Athletic              31
# Barnsley FC                  22
# Swindon Town                 16
# Name: club_name, dtype: int64

# %%
selecao = (dados['fee'].str.contains('Th')) & (dados['fee_cleaned'] > 1)
selecao
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 22970    False
# 22971    False
# 22972    False
# 22973    False
# 22974    False
# Length: 22975, dtype: bool

# %%
## Substituindo os valores '-' or '?' por '0'.

dados.fee_cleaned = dados.fee_cleaned.fillna(0)
dados.drop(columns = ['transfer_period', 'league_name', 'fee', 'season'], axis = 1, inplace = True)
dados.head(10)
# Out:
#           club_name       player_name   age        position  \
# 0  Middlesbrough FC      Tommy Wright  26.0     Left Winger
# 1  Middlesbrough FC  Jonathan Gittens  28.0         defence
# 2  Middlesbrough FC      Chris Morris  28.0      Right-Back
# 3  Middlesbrough FC       Ben Roberts  17.0      Goalkeeper
# 4  Middlesbrough FC         Andy Todd  17.0     Centre-Back
# 5  Middlesbrough FC     Stuart Ripley  24.0    Right Winger
# 6  Middlesbrough FC    Gary Parkinson  24.0      Right-Back
# 7  Middlesbrough FC     Bernie Slaven  31.0  Centre-Forward
# 8  Middlesbrough FC       Andy Payton  24.0          attack
# 9  Middlesbrough FC        Ian Arnold  20.0  Centre-Forward
#
#   club_involved_name transfer_movement  fee_cleaned  year
# 0          Leicester                in         0.91  1992
# 1        Southampton                in         0.25  1992
# 2             Celtic                in         0.00  1992
# 3           Boro U18                in         0.00  1992
# 4           Boro U18                in         0.00  1992
# 5          Blackburn               out         2.00  1992
# 6    Southend United               out         0.00  1992
# 7          Port Vale               out         0.00  1992
# 8             Celtic               out         0.00  1992
# 9    Carlisle United               out         0.00  1992

# %% [markdown]
# ## Liverpool FC

# %%
liverpool = ['Liverpool FC']
selecao = dados['club_name'].isin(liverpool)
liverpool_df = dados[selecao]
liverpool_df
# Out:
#           club_name         player_name   age            position  \
# 255    Liverpool FC        Paul Stewart  27.0  Defensive Midfield
# 256    Liverpool FC         David James  21.0          Goalkeeper
# 257    Liverpool FC     Torben Piechnik  29.0         Centre-Back
# 258    Liverpool FC      Dominic Matteo  18.0           Left-Back
# 259    Liverpool FC    Bruce Grobbelaar  35.0          Goalkeeper
# ...             ...                 ...   ...                 ...
# 22555  Liverpool FC          Ozan Kabak  21.0         Centre-Back
# 22885  Liverpool FC           Luis Díaz  25.0         Left Winger
# 22886  Liverpool FC       Rhys Williams  20.0         Centre-Back
# 22887  Liverpool FC  Nathaniel Phillips  24.0         Centre-Back
# 22888  Liverpool FC       Neco Williams  20.0          Right-Back
#
#       club_involved_name transfer_movement  fee_cleaned  year
# 255                Spurs                in         2.75  1992
# 256              Watford                in         1.40  1992
# 257        FC Copenhagen                in         0.00  1992
# 258        Liverpool U18                in         0.00  1992
# 259           Stoke City                in         0.00  1992
# ...                  ...               ...          ...   ...
# 22555      FC Schalke 04               out         0.00  2021
# 22885           FC Porto                in        47.00  2021
# 22886            Swansea                in         0.00  2021
# 22887        Bournemouth               out         0.00  2021
# 22888             Fulham               out         0.00  2021
#
# [1051 rows x 8 columns]

# %%
liverpool_df.index = range(liverpool_df.shape[0])
liverpool_df
# Out:
#          club_name         player_name   age            position  \
# 0     Liverpool FC        Paul Stewart  27.0  Defensive Midfield
# 1     Liverpool FC         David James  21.0          Goalkeeper
# 2     Liverpool FC     Torben Piechnik  29.0         Centre-Back
# 3     Liverpool FC      Dominic Matteo  18.0           Left-Back
# 4     Liverpool FC    Bruce Grobbelaar  35.0          Goalkeeper
# ...            ...                 ...   ...                 ...
# 1046  Liverpool FC          Ozan Kabak  21.0         Centre-Back
# 1047  Liverpool FC           Luis Díaz  25.0         Left Winger
# 1048  Liverpool FC       Rhys Williams  20.0         Centre-Back
# 1049  Liverpool FC  Nathaniel Phillips  24.0         Centre-Back
# 1050  Liverpool FC       Neco Williams  20.0          Right-Back
#
#      club_involved_name transfer_movement  fee_cleaned  year
# 0                 Spurs                in         2.75  1992
# 1               Watford                in         1.40  1992
# 2         FC Copenhagen                in         0.00  1992
# 3         Liverpool U18                in         0.00  1992
# 4            Stoke City                in         0.00  1992
# ...                 ...               ...          ...   ...
# 1046      FC Schalke 04               out         0.00  2021
# 1047           FC Porto                in        47.00  2021
# 1048            Swansea                in         0.00  2021
# 1049        Bournemouth               out         0.00  2021
# 1050             Fulham               out         0.00  2021
#
# [1051 rows x 8 columns]

# %%
liverpool_df.to_csv('dados/liverpool/liverpool.csv', sep = ';', index = False)

# %% [markdown]
# ## Arsenal

# %%
arsenal = ['Arsenal FC']
selecao = dados['club_name'].isin(arsenal)
arsenal_df = dados[selecao]
arsenal_df
# Out:
#         club_name                player_name   age          position  \
# 114    Arsenal FC                John Jensen  27.0  Central Midfield
# 115    Arsenal FC               Gary McKeown  21.0          midfield
# 116    Arsenal FC                 Ian Selley  18.0  Central Midfield
# 117    Arsenal FC                Alan Miller  23.0        Goalkeeper
# 118    Arsenal FC               Steve Morrow  21.0        Right-Back
# ...           ...                        ...   ...               ...
# 22815  Arsenal FC             Sead Kolasinac  28.0         Left-Back
# 22816  Arsenal FC             Calum Chambers  27.0       Centre-Back
# 22817  Arsenal FC  Pierre-Emerick Aubameyang  32.0    Centre-Forward
# 22818  Arsenal FC                 Pablo Marí  28.0       Centre-Back
# 22819  Arsenal FC              Auston Trusty  23.0       Centre-Back
#
#       club_involved_name transfer_movement  fee_cleaned  year
# 114           Bröndby IF                in          1.6  1992
# 115           Shrewsbury                in          0.0  1992
# 116          Arsenal U18                in          0.0  1992
# 117           Birmingham                in          0.0  1992
# 118               Barnet                in          0.0  1992
# ...                  ...               ...          ...   ...
# 22815          Marseille               out          0.0  2021
# 22816        Aston Villa               out          0.0  2021
# 22817          Barcelona               out          0.0  2021
# 22818     Udinese Calcio               out          0.0  2021
# 22819           Colorado               out          0.0  2021
#
# [934 rows x 8 columns]

# %%
arsenal_df.index = range(arsenal_df.shape[0])
arsenal_df
# Out:
#       club_name                player_name   age          position  \
# 0    Arsenal FC                John Jensen  27.0  Central Midfield
# 1    Arsenal FC               Gary McKeown  21.0          midfield
# 2    Arsenal FC                 Ian Selley  18.0  Central Midfield
# 3    Arsenal FC                Alan Miller  23.0        Goalkeeper
# 4    Arsenal FC               Steve Morrow  21.0        Right-Back
# ..          ...                        ...   ...               ...
# 929  Arsenal FC             Sead Kolasinac  28.0         Left-Back
# 930  Arsenal FC             Calum Chambers  27.0       Centre-Back
# 931  Arsenal FC  Pierre-Emerick Aubameyang  32.0    Centre-Forward
# 932  Arsenal FC                 Pablo Marí  28.0       Centre-Back
# 933  Arsenal FC              Auston Trusty  23.0       Centre-Back
#
#     club_involved_name transfer_movement  fee_cleaned  year
# 0           Bröndby IF                in          1.6  1992
# 1           Shrewsbury                in          0.0  1992
# 2          Arsenal U18                in          0.0  1992
# 3           Birmingham                in          0.0  1992
# 4               Barnet                in          0.0  1992
# ..                 ...               ...          ...   ...
# 929          Marseille               out          0.0  2021
# 930        Aston Villa               out          0.0  2021
# 931          Barcelona               out          0.0  2021
# 932     Udinese Calcio               out          0.0  2021
# 933           Colorado               out          0.0  2021
#
# [934 rows x 8 columns]

# %%
arsenal_df.to_csv('dados/arsenal/arsenal.csv', sep = ';', index = False)

# %% [markdown]
# ## Chelsea

# %%
chelsea = ['Chelsea FC']
selecao = dados['club_name'].isin(chelsea)
chelsea_df = dados[selecao]
chelsea_df
# Out:
#         club_name      player_name   age          position club_involved_name  \
# 124    Chelsea FC   Nigel Spackman  31.0  Central Midfield            Rangers
# 125    Chelsea FC  Anthony Barness  19.0        Right-Back           Charlton
# 126    Chelsea FC     David Hopkin  22.0    Right Midfield             Morton
# 127    Chelsea FC     Mick Harford  33.0    Centre-Forward              Luton
# 128    Chelsea FC      Mal Donaghy  34.0         Left-Back            Man Utd
# ...           ...              ...   ...               ...                ...
# 22449  Chelsea FC    Billy Gilmour  20.0  Central Midfield            Norwich
# 22450  Chelsea FC   Jamal Blackman  27.0        Goalkeeper       Without Club
# 22451  Chelsea FC  Willy Caballero  39.0        Goalkeeper       Without Club
# 22865  Chelsea FC           Kenedy  25.0     Left Midfield           Flamengo
# 22866  Chelsea FC      Lewis Baker  26.0  Central Midfield         Stoke City
#
#       transfer_movement  fee_cleaned  year
# 124                  in        0.600  1992
# 125                  in        0.525  1992
# 126                  in        0.450  1992
# 127                  in        0.350  1992
# 128                  in        0.200  1992
# ...                 ...          ...   ...
# 22449               out        0.000  2021
# 22450               out        0.000  2021
# 22451               out        0.000  2021
# 22865                in        0.000  2021
# 22866               out        0.000  2021
#
# [1273 rows x 8 columns]

# %%
chelsea_df.index = range(chelsea_df.shape[0])
chelsea_df
# Out:
#        club_name      player_name   age          position club_involved_name  \
# 0     Chelsea FC   Nigel Spackman  31.0  Central Midfield            Rangers
# 1     Chelsea FC  Anthony Barness  19.0        Right-Back           Charlton
# 2     Chelsea FC     David Hopkin  22.0    Right Midfield             Morton
# 3     Chelsea FC     Mick Harford  33.0    Centre-Forward              Luton
# 4     Chelsea FC      Mal Donaghy  34.0         Left-Back            Man Utd
# ...          ...              ...   ...               ...                ...
# 1268  Chelsea FC    Billy Gilmour  20.0  Central Midfield            Norwich
# 1269  Chelsea FC   Jamal Blackman  27.0        Goalkeeper       Without Club
# 1270  Chelsea FC  Willy Caballero  39.0        Goalkeeper       Without Club
# 1271  Chelsea FC           Kenedy  25.0     Left Midfield           Flamengo
# 1272  Chelsea FC      Lewis Baker  26.0  Central Midfield         Stoke City
#
#      transfer_movement  fee_cleaned  year
# 0                   in        0.600  1992
# 1                   in        0.525  1992
# 2                   in        0.450  1992
# 3                   in        0.350  1992
# 4                   in        0.200  1992
# ...                ...          ...   ...
# 1268               out        0.000  2021
# 1269               out        0.000  2021
# 1270               out        0.000  2021
# 1271                in        0.000  2021
# 1272               out        0.000  2021
#
# [1273 rows x 8 columns]

# %%
chelsea_df.to_csv('dados/chelsea/chelsea.csv', sep = ';', index = False)

# %% [markdown]
# ## Manchester City

# %%
mancity = ['Manchester City']
selecao = dados['club_name'].isin(mancity)
mancity_df = dados[selecao]
mancity_df
# Out:
#              club_name        player_name   age            position  \
# 179    Manchester City        Rick Holden  27.0       Left Midfield
# 180    Manchester City       Terry Phelan  25.0           Left-Back
# 181    Manchester City    Richard Edghill  17.0          Right-Back
# 182    Manchester City        Adrian Mike  18.0              attack
# 183    Manchester City        John Foster  18.0             defence
# ...                ...                ...   ...                 ...
# 22895  Manchester City  Erik Palmer-Brown  24.0         Centre-Back
# 22896  Manchester City   Philippe Sandler  24.0         Centre-Back
# 22897  Manchester City    Patrick Roberts  24.0        Right Winger
# 22898  Manchester City     Julián Álvarez  22.0      Centre-Forward
# 22899  Manchester City          Luka Ilic  22.0  Attacking Midfield
#
#       club_involved_name transfer_movement  fee_cleaned  year
# 179      Oldham Athletic                in          0.0  1992
# 180         Wimbledon FC                in          0.0  1992
# 181         Man City U18                in          0.0  1992
# 182         Man City U18                in          0.0  1992
# 183         Man City U18                in          0.0  1992
# ...                  ...               ...          ...   ...
# 22895             Troyes               out          0.0  2021
# 22896          Feyenoord               out          0.0  2021
# 22897         Sunderland               out          0.0  2021
# 22898        River Plate               out          0.0  2021
# 22899             Troyes               out          0.0  2021
#
# [1055 rows x 8 columns]

# %%
mancity_df.index = range(mancity_df.shape[0])
mancity_df
# Out:
#             club_name        player_name   age            position  \
# 0     Manchester City        Rick Holden  27.0       Left Midfield
# 1     Manchester City       Terry Phelan  25.0           Left-Back
# 2     Manchester City    Richard Edghill  17.0          Right-Back
# 3     Manchester City        Adrian Mike  18.0              attack
# 4     Manchester City        John Foster  18.0             defence
# ...               ...                ...   ...                 ...
# 1050  Manchester City  Erik Palmer-Brown  24.0         Centre-Back
# 1051  Manchester City   Philippe Sandler  24.0         Centre-Back
# 1052  Manchester City    Patrick Roberts  24.0        Right Winger
# 1053  Manchester City     Julián Álvarez  22.0      Centre-Forward
# 1054  Manchester City          Luka Ilic  22.0  Attacking Midfield
#
#      club_involved_name transfer_movement  fee_cleaned  year
# 0       Oldham Athletic                in          0.0  1992
# 1          Wimbledon FC                in          0.0  1992
# 2          Man City U18                in          0.0  1992
# 3          Man City U18                in          0.0  1992
# 4          Man City U18                in          0.0  1992
# ...                 ...               ...          ...   ...
# 1050             Troyes               out          0.0  2021
# 1051          Feyenoord               out          0.0  2021
# 1052         Sunderland               out          0.0  2021
# 1053        River Plate               out          0.0  2021
# 1054             Troyes               out          0.0  2021
#
# [1055 rows x 8 columns]

# %%
mancity_df.to_csv('dados/mancity/mancity.csv', sep = ';', index = False)

# %% [markdown]
# ## Manchester United

# %%
manutd = ['Manchester United']
selecao = dados['club_name'].isin(manutd)
manutd_df = dados[selecao]
manutd_df
# Out:
#                club_name        player_name   age            position  \
# 68     Manchester United        Dion Dublin  23.0      Centre-Forward
# 69     Manchester United       Pat McGibbon  18.0         Centre-Back
# 70     Manchester United        Andy Arnott  18.0  Defensive Midfield
# 71     Manchester United   Kevin Pilkington  18.0          Goalkeeper
# 72     Manchester United       Simon Davies  18.0            midfield
# ...                  ...                ...   ...                 ...
# 22900  Manchester United      Axel Tuanzebe  24.0         Centre-Back
# 22901  Manchester United        Teden Mengi  19.0         Centre-Back
# 22902  Manchester United    Anthony Martial  26.0      Centre-Forward
# 22903  Manchester United        Amad Diallo  19.0        Right Winger
# 22904  Manchester United  Donny van de Beek  24.0    Central Midfield
#
#       club_involved_name transfer_movement  fee_cleaned  year
# 68        Cambridge Utd.                in        1.500  1992
# 69             Portadown                in        0.225  1992
# 70         Gillingham FC                in        0.000  1992
# 71           Man Utd U18                in        0.000  1992
# 72           Man Utd U18                in        0.000  1992
# ...                  ...               ...          ...   ...
# 22900         SSC Napoli               out        0.600  2021
# 22901         Birmingham               out        0.000  2021
# 22902         Sevilla FC               out        0.000  2021
# 22903            Rangers               out        0.000  2021
# 22904            Everton               out        0.000  2021
#
# [980 rows x 8 columns]

# %%
manutd_df.index = range(manutd_df.shape[0])
manutd_df
# Out:
#              club_name        player_name   age            position  \
# 0    Manchester United        Dion Dublin  23.0      Centre-Forward
# 1    Manchester United       Pat McGibbon  18.0         Centre-Back
# 2    Manchester United        Andy Arnott  18.0  Defensive Midfield
# 3    Manchester United   Kevin Pilkington  18.0          Goalkeeper
# 4    Manchester United       Simon Davies  18.0            midfield
# ..                 ...                ...   ...                 ...
# 975  Manchester United      Axel Tuanzebe  24.0         Centre-Back
# 976  Manchester United        Teden Mengi  19.0         Centre-Back
# 977  Manchester United    Anthony Martial  26.0      Centre-Forward
# 978  Manchester United        Amad Diallo  19.0        Right Winger
# 979  Manchester United  Donny van de Beek  24.0    Central Midfield
#
#     club_involved_name transfer_movement  fee_cleaned  year
# 0       Cambridge Utd.                in        1.500  1992
# 1            Portadown                in        0.225  1992
# 2        Gillingham FC                in        0.000  1992
# 3          Man Utd U18                in        0.000  1992
# 4          Man Utd U18                in        0.000  1992
# ..                 ...               ...          ...   ...
# 975         SSC Napoli               out        0.600  2021
# 976         Birmingham               out        0.000  2021
# 977         Sevilla FC               out        0.000  2021
# 978            Rangers               out        0.000  2021
# 979            Everton               out        0.000  2021
#
# [980 rows x 8 columns]

# %%
manutd_df.to_csv('dados/manutd/manutd.csv', sep = ';', index = False)

# %% [markdown]
# ## Tottenham

# %%
tottenham = ['Tottenham Hotspur']
selecao = dados['club_name'].isin(tottenham)
tottenham_df = dados[selecao]
tottenham_df
# Out:
#                club_name       player_name   age            position  \
# 232    Tottenham Hotspur  Teddy Sheringham  26.0      Centre-Forward
# 233    Tottenham Hotspur   Darren Anderton  20.0      Right Midfield
# 234    Tottenham Hotspur       Jason Cundy  22.0         Centre-Back
# 235    Tottenham Hotspur      Neil Ruddock  24.0         Centre-Back
# 236    Tottenham Hotspur       Dean Austin  22.0          Right-Back
# ...                  ...               ...   ...                 ...
# 22938  Tottenham Hotspur         Dele Alli  25.0  Attacking Midfield
# 22939  Tottenham Hotspur       Jack Clarke  21.0        Right Winger
# 22940  Tottenham Hotspur         Bryan Gil  20.0         Left Winger
# 22941  Tottenham Hotspur  Giovani Lo Celso  25.0    Central Midfield
# 22942  Tottenham Hotspur    Alfie Whiteman  23.0          Goalkeeper
#
#       club_involved_name transfer_movement  fee_cleaned  year
# 232         Nottm Forest                in        3.150  1992
# 233           Portsmouth                in        2.700  1992
# 234              Chelsea                in        0.875  1992
# 235          Southampton                in        0.850  1992
# 236      Southend United                in        0.000  1992
# ...                  ...               ...          ...   ...
# 22938            Everton               out        0.000  2021
# 22939         Sunderland               out        0.000  2021
# 22940           Valencia               out        0.000  2021
# 22941         Villarreal               out        0.000  2021
# 22942          Degerfors               out        0.000  2021
#
# [1196 rows x 8 columns]

# %%
tottenham_df.index = range(tottenham_df.shape[0])
tottenham_df
# Out:
#               club_name       player_name   age            position  \
# 0     Tottenham Hotspur  Teddy Sheringham  26.0      Centre-Forward
# 1     Tottenham Hotspur   Darren Anderton  20.0      Right Midfield
# 2     Tottenham Hotspur       Jason Cundy  22.0         Centre-Back
# 3     Tottenham Hotspur      Neil Ruddock  24.0         Centre-Back
# 4     Tottenham Hotspur       Dean Austin  22.0          Right-Back
# ...                 ...               ...   ...                 ...
# 1191  Tottenham Hotspur         Dele Alli  25.0  Attacking Midfield
# 1192  Tottenham Hotspur       Jack Clarke  21.0        Right Winger
# 1193  Tottenham Hotspur         Bryan Gil  20.0         Left Winger
# 1194  Tottenham Hotspur  Giovani Lo Celso  25.0    Central Midfield
# 1195  Tottenham Hotspur    Alfie Whiteman  23.0          Goalkeeper
#
#      club_involved_name transfer_movement  fee_cleaned  year
# 0          Nottm Forest                in        3.150  1992
# 1            Portsmouth                in        2.700  1992
# 2               Chelsea                in        0.875  1992
# 3           Southampton                in        0.850  1992
# 4       Southend United                in        0.000  1992
# ...                 ...               ...          ...   ...
# 1191            Everton               out        0.000  2021
# 1192         Sunderland               out        0.000  2021
# 1193           Valencia               out        0.000  2021
# 1194         Villarreal               out        0.000  2021
# 1195          Degerfors               out        0.000  2021
#
# [1196 rows x 8 columns]

# %%
tottenham_df.to_csv('dados/tottenham/tottenham.csv', sep = ';', index = False)
